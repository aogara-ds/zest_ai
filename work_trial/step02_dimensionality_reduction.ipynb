# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook reports the Pearson correlation between each variable and the target outcome. While these correlations cannot tell us exactly which variables will offer the best performance in the context of a holistic productionized model, they're a good starting point for dimensionality reduction.

# %%
import numpy as np
import pandas as pd
import scipy.stats

from utils import bad_rate_by_category

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ## Data

# %%
# Import data and data dictionary
data = pd.read_pickle('output_data/01_data.pkl')

data_dict = pd.read_pickle('output_data/01_data_dict.pkl')

# %% [markdown]
# ## Potential Features

# %%
# Designate eda categories as containing features
prelim_feature_dict = ['credit_score', 'personal_finance', 'other_info']
data_dict['potential_feature'] = data_dict.apply(lambda x: x.eda_category in prelim_feature_dict, axis=1)

# %% [markdown]
# ## Pearson Correlations

# %%
# Function to evaluate pearson correlation
def correlate_pearson(var1, var2, data):
    # Drop rows without either input or output variable
    data_notna = data.dropna(axis=0, subset=[var1, var2])
    
    # Run Pearson correlation
    pearson, pearson_p = scipy.stats.pearsonr(data_notna[var1], data_notna[var2])
    
    return pearson, pearson_p

# %%
# Designate list of potential model features
potential_features = data_dict.loc[data_dict['potential_feature']==True, 'variable'].values

# For each potential feature, calculate Pearson's correlation 
# and its p-value and store them in the data dictionary
for var in potential_features:
    pearson, pearson_p = correlate_pearson(var, 'bad', data)
    data_dict.loc[data_dict['variable']==var,'pearson'] = pearson
    data_dict.loc[data_dict['variable']==var,'pearson_p'] = pearson_p

# %%
data_dict.sort_values('pearson_p').reset_index(drop=True)
# Out:
#                                       variable       var_dtype  \
# 0                              raw_FICO_retail           int64
# 1                  payment_frequency_bi_weekly           uint8
# 2                  payment_frequency_per_month           int64
# 3                             raw_FICO_telecom           int64
# 4                           raw_FICO_bank_card           int64
# 5                               raw_FICO_money           int64
# 6                    payment_frequency_monthly           uint8
# 7               payment_frequency_semi_monthly           uint8
# 8                     payment_frequency_weekly           uint8
# 9                 bank_account_duration_months         float64
# 10      bank_account_duration_6_months_or_less           uint8
# 11              bank_account_duration_3+_years           uint8
# 12  how_use_money_pay_off_loans_overdrawn_acct           uint8
# 13                         expense_type_credit           uint8
# 14                  application_month_of_cycle           int64
# 15                 how_use_money_gifts_leisure           uint8
# 16                        home_phone_type_home           uint8
# 17              residence_duration_7_12_months           uint8
# 18                         how_use_money_bills           uint8
# 19                      home_phone_type_mobile           uint8
# 20                 residence_duration_3+_years           uint8
# 21                   residence_duration_months         float64
# 22                                bank_id_0297           uint8
# 23                                bank_id_0154           uint8
# 24                 how_use_money_bills_general           uint8
# 25                                bank_id_0215           uint8
# 26                       other_phone_type_work           uint8
# 27                                bank_id_7751           uint8
# 28                 how_use_money_rent_mortgage           uint8
# 29                                bank_id_9999           uint8
# 30             bank_account_duration_1_2_years           uint8
# 31                     other_phone_type_mobile           uint8
# 32                         how_use_money_other           uint8
# 33                     how_use_money_won't_say           uint8
# 34                       how_use_money_medical           uint8
# 35                        expense_type_general           uint8
# 36                         monthly_rent_amount           int64
# 37             email_duration_3_months_or_less           uint8
# 38           bank_account_duration_7_12_months           uint8
# 39                residence_duration_1_2_years           uint8
# 40                    how_use_money_bills_auto           uint8
# 41                        rent_to_income_ratio         float64
# 42                        expense_type_housing           uint8
# 43                        how_use_money_school           uint8
# 44                      expense_type_education           uint8
# 45                          how_use_money_rent           uint8
# 46                 expense_type_transportation           uint8
# 47                       email_duration_months         float64
# 48                               raw_l2c_score           int64
# 49                                bank_id_0005           uint8
# 50                        expense_type_medical           uint8
# 51                       monthly_income_amount           int64
# 52                        home_phone_type_work           uint8
# 53               email_duration_1_year_or_more           uint8
# 54                     application_day_of_year           int64
# 55                                bank_id_7955           uint8
# 56         residence_duration_6_months_or_less           uint8
# 57          how_use_money_bills_home_utilities           uint8
# 58                  email_duration_4_12_months           uint8
# 59                           how_use_money_car           uint8
# 60                       other_phone_type_home           uint8
# 61                 how_use_money_bills_medical           uint8
# 62                     application_hour_of_day           int64
# 63                                 customer_id          object
# 64                            amount_requested           int64
# 65                                  birth_date  datetime64[ns]
# 66                                      status          object
# 67                            application_when  datetime64[ns]
# 68                               loan_duration           int64
# 69                                num_payments           int64
# 70                              payment_amount         float64
# 71                             amount_approved           int64
# 72                           duration_approved           int64
# 73                     payment_amount_approved         float64
# 74                                 address_zip          object
# 75                                       email          object
# 76                         bank_routing_number          object
# 77                                      idLoan          object
# 78                                         bad           uint8
#
#         eda_category  categorical  coverage  potential_feature   pearson  \
# 0       credit_score            0  1.000000               True -0.180558
# 1   personal_finance           -1  1.000000               True  0.177818
# 2   personal_finance            0  1.000000               True  0.160181
# 3       credit_score            0  1.000000               True -0.156673
# 4       credit_score            0  1.000000               True -0.152722
# 5       credit_score            0  1.000000               True -0.152437
# 6   personal_finance           -1  1.000000               True -0.136097
# 7   personal_finance           -1  1.000000               True -0.129028
# 8   personal_finance           -1  1.000000               True  0.103345
# 9         other_info            0  0.998462               True -0.102491
# 10  personal_finance           -1  1.000000               True  0.102211
# 11  personal_finance           -1  1.000000               True -0.096812
# 12  personal_finance           -1  1.000000               True -0.095151
# 13  personal_finance           -1  1.000000               True -0.095151
# 14        other_info            0  1.000000               True -0.086858
# 15  personal_finance           -1  1.000000               True -0.074237
# 16        other_info           -1  1.000000               True -0.072168
# 17        other_info           -1  1.000000               True  0.071946
# 18  personal_finance           -1  1.000000               True  0.066545
# 19        other_info           -1  1.000000               True  0.065296
# 20        other_info           -1  1.000000               True -0.064986
# 21        other_info            0  1.000000               True -0.063044
# 22  personal_finance           -1  1.000000               True  0.060603
# 23  personal_finance           -1  1.000000               True -0.060042
# 24  personal_finance           -1  1.000000               True -0.056442
# 25  personal_finance           -1  1.000000               True -0.055170
# 26        other_info           -1  1.000000               True  0.054079
# 27  personal_finance           -1  1.000000               True -0.053980
# 28  personal_finance           -1  1.000000               True -0.046296
# 29  personal_finance           -1  1.000000               True  0.041082
# 30  personal_finance           -1  1.000000               True  0.040795
# 31        other_info           -1  1.000000               True  0.038723
# 32  personal_finance           -1  1.000000               True  0.036982
# 33  personal_finance           -1  1.000000               True  0.036005
# 34  personal_finance           -1  1.000000               True -0.035903
# 35  personal_finance           -1  1.000000               True  0.035075
# 36  personal_finance            0  1.000000               True -0.034729
# 37        other_info           -1  1.000000               True -0.033669
# 38  personal_finance           -1  1.000000               True -0.032270
# 39        other_info           -1  1.000000               True  0.028757
# 40  personal_finance           -1  1.000000               True  0.027949
# 41  personal_finance            0  1.000000               True -0.026568
# 42  personal_finance           -1  1.000000               True -0.025325
# 43  personal_finance           -1  1.000000               True -0.025288
# 44  personal_finance           -1  1.000000               True -0.025288
# 45  personal_finance           -1  1.000000               True -0.025288
# 46  personal_finance           -1  1.000000               True  0.025090
# 47        other_info            0  1.000000               True  0.017248
# 48      credit_score            0  1.000000               True  0.017142
# 49  personal_finance           -1  1.000000               True  0.016410
# 50  personal_finance           -1  1.000000               True -0.016085
# 51  personal_finance            0  1.000000               True -0.014465
# 52        other_info           -1  1.000000               True  0.014284
# 53        other_info           -1  1.000000               True  0.014116
# 54        other_info            0  1.000000               True  0.013557
# 55  personal_finance           -1  1.000000               True  0.008873
# 56        other_info           -1  1.000000               True -0.006305
# 57  personal_finance           -1  1.000000               True  0.006194
# 58        other_info           -1  1.000000               True  0.006066
# 59  personal_finance           -1  1.000000               True  0.003751
# 60        other_info           -1  1.000000               True -0.003088
# 61  personal_finance           -1  1.000000               True  0.002386
# 62        other_info            0  1.000000               True  0.000076
# 63       performance            1  1.000000              False       NaN
# 64             terms            0  1.000000              False       NaN
# 65         protected            1  1.000000              False       NaN
# 66             terms            1  1.000000              False       NaN
# 67       application            1  1.000000              False       NaN
# 68       application            0  1.000000              False       NaN
# 69             terms            0  1.000000              False       NaN
# 70             terms            0  1.000000              False       NaN
# 71             terms            0  1.000000              False       NaN
# 72             terms            0  1.000000              False       NaN
# 73             terms            0  0.966154              False       NaN
# 74         protected            1  1.000000              False       NaN
# 75         protected            1  1.000000              False       NaN
# 76         protected            1  1.000000              False       NaN
# 77       performance            1  1.000000              False       NaN
# 78       performance            0  1.000000              False       NaN
#
#     pearson_p
# 0    0.000004
# 1    0.000005
# 2    0.000041
# 3    0.000060
# 4    0.000093
# 5    0.000096
# 6    0.000503
# 7    0.000977
# 8    0.008370
# 9    0.008926
# 10   0.009115
# 11   0.013538
# 12   0.015236
# 13   0.015236
# 14   0.026804
# 15   0.058540
# 16   0.065947
# 17   0.066787
# 18   0.090041
# 19   0.096251
# 20   0.097846
# 21   0.108316
# 22   0.122701
# 23   0.126211
# 24   0.150612
# 25   0.160041
# 26   0.168479
# 27   0.169265
# 28   0.238525
# 29   0.295642
# 30   0.299038
# 31   0.324267
# 32   0.346523
# 33   0.359408
# 34   0.360782
# 35   0.371961
# 36   0.376702
# 37   0.391451
# 38   0.411445
# 39   0.464229
# 40   0.476875
# 41   0.498931
# 42   0.519237
# 43   0.519839
# 44   0.519839
# 45   0.519839
# 46   0.523116
# 47   0.660712
# 48   0.662671
# 49   0.676235
# 50   0.682292
# 51   0.712799
# 52   0.716242
# 53   0.719432
# 54   0.730101
# 55   0.821377
# 56   0.872531
# 57   0.874758
# 58   0.877334
# 59   0.923953
# 60   0.937360
# 61   0.951595
# 62   0.998465
# 63        NaN
# 64        NaN
# 65        NaN
# 66        NaN
# 67        NaN
# 68        NaN
# 69        NaN
# 70        NaN
# 71        NaN
# 72        NaN
# 73        NaN
# 74        NaN
# 75        NaN
# 76        NaN
# 77        NaN
# 78        NaN

# %% [markdown]
# ## Export Data

# %%
data.to_pickle('output_data/02_data.pkl')
data_dict.to_pickle('output_data/02_data_dict.pkl')
