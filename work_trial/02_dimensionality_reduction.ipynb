# %% [markdown]
# # Introduction

# %% [markdown]
# Evaluating Correlations:
# * For all categorical variables, show bar chart of default rates.
# * For all continuous variables, show point biserial correlation or ANOVA.
# * * ANOVA gives p-value of equal means. Point biserial is tougher to compare.
# * Futher dimenstionality reduction: Run an LR, show coefficient, p value, and regularizer results.
# * Chi-squared for categorical variables?
#
# How do you evaluate the correlation between two categorical variables: ANOVA or KW?
# * ANOVA gives the probability that different samples are drawn from the same population. It assumes a normally-distributed dependent variable, which binary data is not, but [academics have argued](https://journals.sagepub.com/doi/abs/10.3102/00346543042003237?journalCode=rera) that it can be accurately used for binary data anyways.
# * Kruskal Wallis is a non-parametric alternative to ANOVA that similarly tests whether series of observations come from the same distribution. [Other academics have argued](https://journals.sagepub.com/doi/abs/10.3102/00346543051004499?journalCode=rera) that it more accurately assesses correlations between categorical values. But I've used this before and gotten unclear results. I'd like to discuss with the team before choosing a method here.
# * Decision: Chi Squared Test of Association. Using scipy.stats.chi2_contingency, as documented [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi2_contingency.html) and implemented [here](https://stackoverflow.com/questions/25139326/chi-squared-test-in-python).

# %%
import numpy as np
import pandas as pd
import scipy.stats

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ## Data

# %%
# Import data and data dictionary
data = pd.read_pickle('output_data/01_data.pkl')

data_dict = pd.read_pickle('output_data/01_data_dict.pkl')

# %% [markdown]
# ## Potential Features

# %%
# Designate eda categories as containing features
prelim_feature_dict = ['credit_score', 'personal_finance', 'other_info']
data_dict['potential_feature'] = data_dict.apply(lambda x: x.eda_category in prelim_feature_dict, axis=1)

# %% [markdown]
# ## Pearson Correlations

# %%
# Function to evaluate pearson correlation
def correlate_pearson(var1, var2, data):
    # Drop rows without either input or output variable
    data_notna = data.dropna(axis=0, subset=[var1, var2])
    
    # Run Pearson correlation
    pearson, pearson_p = scipy.stats.pearsonr(data_notna[var1], data_notna[var2])
    
    return pearson, pearson_p

# %%
# Designate list of potential model features
potential_features = data_dict.loc[data_dict['potential_feature']==True, 'variable'].values

# For each potential feature, calculate Pearson's correlation 
# and its p-value and store them in the data dictionary
for var in potential_features:
    pearson, pearson_p = correlate_pearson(var, 'bad', data)
    data_dict.loc[data_dict['variable']==var,'pearson'] = pearson
    data_dict.loc[data_dict['variable']==var,'pearson_p'] = pearson_p

# %%
data_dict.sort_values('eda_category').reset_index(drop=True)
# Out:
#                                       variable       var_dtype  \
# 0                             application_when  datetime64[ns]
# 1                                loan_duration           int64
# 2                               raw_FICO_money           int64
# 3                           raw_FICO_bank_card           int64
# 4                              raw_FICO_retail           int64
# 5                             raw_FICO_telecom           int64
# 6                                raw_l2c_score           int64
# 7                        other_phone_type_work           uint8
# 8                      application_day_of_year           int64
# 9                        email_duration_months         float64
# 10                   residence_duration_months         float64
# 11                bank_account_duration_months         float64
# 12                        home_phone_type_home           uint8
# 13                      home_phone_type_mobile           uint8
# 14                   application_month_of_year           int64
# 15                       other_phone_type_home           uint8
# 16                        home_phone_type_work           uint8
# 17                  email_duration_4_12_months           uint8
# 18                residence_duration_1_2_years           uint8
# 19                 residence_duration_3+_years           uint8
# 20         residence_duration_6_months_or_less           uint8
# 21             email_duration_3_months_or_less           uint8
# 22               email_duration_1_year_or_more           uint8
# 23              residence_duration_7_12_months           uint8
# 24                     other_phone_type_mobile           uint8
# 25                     application_hour_of_day           int64
# 26                                 customer_id          object
# 27                                         bad           uint8
# 28                                      idLoan          object
# 29                                bank_id_7955           uint8
# 30                         how_use_money_other           uint8
# 31                                bank_id_7751           uint8
# 32                         monthly_rent_amount           int64
# 33  how_use_money_pay_off_loans_overdrawn_acct           uint8
# 34                                bank_id_0215           uint8
# 35                    payment_frequency_weekly           uint8
# 36              bank_account_duration_3+_years           uint8
# 37                     how_use_money_won't_say           uint8
# 38                 expense_type_transportation           uint8
# 39                       how_use_money_medical           uint8
# 40                        how_use_money_school           uint8
# 41                                bank_id_0297           uint8
# 42                                bank_id_0005           uint8
# 43             bank_account_duration_1_2_years           uint8
# 44                                bank_id_9999           uint8
# 45                         expense_type_credit           uint8
# 46                        expense_type_medical           uint8
# 47                      expense_type_education           uint8
# 48                        rent_to_income_ratio         float64
# 49           bank_account_duration_7_12_months           uint8
# 50              payment_frequency_semi_monthly           uint8
# 51                          how_use_money_rent           uint8
# 52                       monthly_income_amount           int64
# 53                 payment_frequency_per_month           int64
# 54                 how_use_money_bills_general           uint8
# 55                 how_use_money_bills_medical           uint8
# 56                        expense_type_general           uint8
# 57                           how_use_money_car           uint8
# 58                 payment_frequency_bi_weekly           uint8
# 59                                bank_id_0154           uint8
# 60                    how_use_money_bills_auto           uint8
# 61      bank_account_duration_6_months_or_less           uint8
# 62                         how_use_money_bills           uint8
# 63                 how_use_money_rent_mortgage           uint8
# 64                   payment_frequency_monthly           uint8
# 65          how_use_money_bills_home_utilities           uint8
# 66                 how_use_money_gifts_leisure           uint8
# 67                        expense_type_housing           uint8
# 68                                  birth_date  datetime64[ns]
# 69                                 address_zip          object
# 70                                       email          object
# 71                         bank_routing_number          object
# 72                              payment_amount         float64
# 73                            amount_requested           int64
# 74                           duration_approved           int64
# 75                                num_payments           int64
# 76                     payment_amount_approved         float64
# 77                                      status          object
# 78                             amount_approved           int64
#
#         eda_category  categorical  coverage  potential_feature   pearson  \
# 0        application            1  1.000000              False       NaN
# 1        application            0  1.000000              False       NaN
# 2       credit_score            0  1.000000               True -0.152437
# 3       credit_score            0  1.000000               True -0.152722
# 4       credit_score            0  1.000000               True -0.180558
# 5       credit_score            0  1.000000               True -0.156673
# 6       credit_score            0  1.000000               True  0.017142
# 7         other_info           -1  1.000000               True  0.054079
# 8         other_info            0  1.000000               True  0.013557
# 9         other_info            0  1.000000               True  0.017248
# 10        other_info            0  1.000000               True -0.063044
# 11        other_info            0  0.998462               True -0.102491
# 12        other_info           -1  1.000000               True -0.072168
# 13        other_info           -1  1.000000               True  0.065296
# 14        other_info            0  1.000000               True -0.086858
# 15        other_info           -1  1.000000               True -0.003088
# 16        other_info           -1  1.000000               True  0.014284
# 17        other_info           -1  1.000000               True  0.006066
# 18        other_info           -1  1.000000               True  0.028757
# 19        other_info           -1  1.000000               True -0.064986
# 20        other_info           -1  1.000000               True -0.006305
# 21        other_info           -1  1.000000               True -0.033669
# 22        other_info           -1  1.000000               True  0.014116
# 23        other_info           -1  1.000000               True  0.071946
# 24        other_info           -1  1.000000               True  0.038723
# 25        other_info            0  1.000000               True  0.000076
# 26       performance            1  1.000000              False       NaN
# 27       performance            0  1.000000              False       NaN
# 28       performance            1  1.000000              False       NaN
# 29  personal_finance           -1  1.000000               True  0.008873
# 30  personal_finance           -1  1.000000               True  0.036982
# 31  personal_finance           -1  1.000000               True -0.053980
# 32  personal_finance            0  1.000000               True -0.034729
# 33  personal_finance           -1  1.000000               True -0.095151
# 34  personal_finance           -1  1.000000               True -0.055170
# 35  personal_finance           -1  1.000000               True  0.103345
# 36  personal_finance           -1  1.000000               True -0.096812
# 37  personal_finance           -1  1.000000               True  0.036005
# 38  personal_finance           -1  1.000000               True  0.025090
# 39  personal_finance           -1  1.000000               True -0.035903
# 40  personal_finance           -1  1.000000               True -0.025288
# 41  personal_finance           -1  1.000000               True  0.060603
# 42  personal_finance           -1  1.000000               True  0.016410
# 43  personal_finance           -1  1.000000               True  0.040795
# 44  personal_finance           -1  1.000000               True  0.041082
# 45  personal_finance           -1  1.000000               True -0.095151
# 46  personal_finance           -1  1.000000               True -0.016085
# 47  personal_finance           -1  1.000000               True -0.025288
# 48  personal_finance            0  1.000000               True -0.026568
# 49  personal_finance           -1  1.000000               True -0.032270
# 50  personal_finance           -1  1.000000               True -0.129028
# 51  personal_finance           -1  1.000000               True -0.025288
# 52  personal_finance            0  1.000000               True -0.014465
# 53  personal_finance            0  1.000000               True  0.160181
# 54  personal_finance           -1  1.000000               True -0.056442
# 55  personal_finance           -1  1.000000               True  0.002386
# 56  personal_finance           -1  1.000000               True  0.035075
# 57  personal_finance           -1  1.000000               True  0.003751
# 58  personal_finance           -1  1.000000               True  0.177818
# 59  personal_finance           -1  1.000000               True -0.060042
# 60  personal_finance           -1  1.000000               True  0.027949
# 61  personal_finance           -1  1.000000               True  0.102211
# 62  personal_finance           -1  1.000000               True  0.066545
# 63  personal_finance           -1  1.000000               True -0.046296
# 64  personal_finance           -1  1.000000               True -0.136097
# 65  personal_finance           -1  1.000000               True  0.006194
# 66  personal_finance           -1  1.000000               True -0.074237
# 67  personal_finance           -1  1.000000               True -0.025325
# 68         protected            1  1.000000              False       NaN
# 69         protected            1  1.000000              False       NaN
# 70         protected            1  1.000000              False       NaN
# 71         protected            1  1.000000              False       NaN
# 72             terms            0  1.000000              False       NaN
# 73             terms            0  1.000000              False       NaN
# 74             terms            0  1.000000              False       NaN
# 75             terms            0  1.000000              False       NaN
# 76             terms            0  0.966154              False       NaN
# 77             terms            1  1.000000              False       NaN
# 78             terms            0  1.000000              False       NaN
#
#     pearson_p
# 0         NaN
# 1         NaN
# 2    0.000096
# 3    0.000093
# 4    0.000004
# 5    0.000060
# 6    0.662671
# 7    0.168479
# 8    0.730101
# 9    0.660712
# 10   0.108316
# 11   0.008926
# 12   0.065947
# 13   0.096251
# 14   0.026804
# 15   0.937360
# 16   0.716242
# 17   0.877334
# 18   0.464229
# 19   0.097846
# 20   0.872531
# 21   0.391451
# 22   0.719432
# 23   0.066787
# 24   0.324267
# 25   0.998465
# 26        NaN
# 27        NaN
# 28        NaN
# 29   0.821377
# 30   0.346523
# 31   0.169265
# 32   0.376702
# 33   0.015236
# 34   0.160041
# 35   0.008370
# 36   0.013538
# 37   0.359408
# 38   0.523116
# 39   0.360782
# 40   0.519839
# 41   0.122701
# 42   0.676235
# 43   0.299038
# 44   0.295642
# 45   0.015236
# 46   0.682292
# 47   0.519839
# 48   0.498931
# 49   0.411445
# 50   0.000977
# 51   0.519839
# 52   0.712799
# 53   0.000041
# 54   0.150612
# 55   0.951595
# 56   0.371961
# 57   0.923953
# 58   0.000005
# 59   0.126211
# 60   0.476875
# 61   0.009115
# 62   0.090041
# 63   0.238525
# 64   0.000503
# 65   0.874758
# 66   0.058540
# 67   0.519237
# 68        NaN
# 69        NaN
# 70        NaN
# 71        NaN
# 72        NaN
# 73        NaN
# 74        NaN
# 75        NaN
# 76        NaN
# 77        NaN
# 78        NaN

# %% [markdown]
# ## Sets of Features

# %% [markdown]
# # Confounders

# %% [markdown]
# Characteristics which affect the performance of the loan in this dataset, but which cannot be used in future underwriting. Hypothetically you'd want to 'control for' these characteristics by adjusting performance by the underlying likelihood of default based on those confounding characteristics which cannot be used by the model. But this is not a run-of-the-mill exercise, and for this analysis I'll simply call out the risks presented.

# %%
# Loan Duration
display(bad_rate_by_category('duration_approved', data))
print('My hypothesis that longer loan durations allow more time for default is incorrect.')
print('Bad rates remain consistent across different loan durations.')

# %% [markdown]
# ## Export Data

# %%
data.to_pickle('output_data/02_data.pkl')
data_dict.to_pickle('output_data/02_data_dict.pkl')
