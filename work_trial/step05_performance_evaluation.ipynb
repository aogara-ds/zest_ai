# %% [markdown]
# # Introduction

# %% [markdown]
# Next Steps
# 1/5/2022
#
# What am I going to present?
# * Underwriting Policies. Market segmentation, credit scoring, differentiated pricing.
# * XGBoost. Hyperparameter tuning, cross validation, performance. Here is the credit score to use.
# * Fair Lending performance.

# %%
import os
import numpy as np
import pandas as pd
import scipy.stats
import seaborn as sns
import matplotlib.pyplot as plt

import multiprocessing

import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Data

# %% [markdown]
# Let's load up the results of the last notebook. Because we're building an alternative credit score, we'll only consider models that do not use FICO as an input.

# %%
# Load performance results from previous notebook 

# Store everything in one performance dataframe
performance = pd.DataFrame()

# Iterate through feature sets and search numbers
feature_sets = ['no_credit']
search_numbers = ['0001', '0002', '0003']

# For each search
for i in search_numbers:
    # For each feature set
    for name in feature_sets:
        # Store data in a dictionary
        df = pd.read_pickle(f'output_data/04_{name}_performance_{i}.pkl')
        
        # Track the features it used and the grid search it came from
        df['features'] = name
        df['grid_search'] = i
        
        # Append to the overall performance DF
        performance = performance.append(df)

# %% [markdown]
# #### Let's rename some of these columns.

# %%
performance.rename({'mean_fit_time': 'training_seconds'},
                   inplace = True)

# %% [markdown]
# #### Build some new columns.

# %%
performance = performance.reset_index()
performance = performance.rename({'index': 'model_id'}, axis=1)

performance['framework'] = 'xgboost'

# %% [markdown]
# #### Take a look.

# %%
performance.head()
# Out:
#    model_id  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0       0.484207      0.033851         0.042410        0.005060
# 1         1       0.490694      0.061369         0.040287        0.003249
# 2         2       0.568504      0.037977         0.032832        0.003758
# 3         3       0.524090      0.039263         0.032482        0.004320
# 4         4       0.509604      0.026835         0.029784        0.000767
#
#   param_booster param_eta param_eval_metric param_gamma param_max_depth  ...  \
# 0        gbtree      0.01           logloss           0               2  ...
# 1        gbtree      0.01           logloss           0               2  ...
# 2        gbtree      0.01           logloss           0               2  ...
# 3        gbtree      0.01           logloss           0               2  ...
# 4        gbtree      0.01           logloss           0               2  ...
#
#   split1_test_roc_auc split2_test_roc_auc split3_test_roc_auc  \
# 0            0.480492            0.382951            0.489836
# 1            0.469836            0.388852            0.540656
# 2            0.460820            0.421639            0.509508
# 3            0.467869            0.379836            0.521803
# 4            0.445410            0.385246            0.481311
#
#   split4_test_roc_auc mean_test_roc_auc std_test_roc_auc  rank_test_roc_auc  \
# 0            0.556616          0.494504         0.065054                 94
# 1            0.500823          0.498427         0.068356                 91
# 2            0.549375          0.500203         0.052468                 85
# 3            0.500823          0.492066         0.068896                103
# 4            0.589203          0.489414         0.072114                113
#
#     features  grid_search  framework
# 0  no_credit         0001    xgboost
# 1  no_credit         0001    xgboost
# 2  no_credit         0001    xgboost
# 3  no_credit         0001    xgboost
# 4  no_credit         0001    xgboost
#
# [5 rows x 67 columns]

# %% [markdown]
# #### Build a new Performance Dictionary

# %%
performance_dict = pd.DataFrame(performance.dtypes)
performance_dict = performance_dict.reset_index()
performance_dict.rename({0: 'var_dtype',
                        'index': 'var_name'}, 
                        axis=1, 
                        inplace = True)

performance_dict.head()
# Out:
#           var_name var_dtype
# 0         model_id     int64
# 1    mean_fit_time   float64
# 2     std_fit_time   float64
# 3  mean_score_time   float64
# 4   std_score_time   float64

# %%
performance_dict.head()
# Out:
#           var_name var_dtype
# 0         model_id     int64
# 1    mean_fit_time   float64
# 2     std_fit_time   float64
# 3  mean_score_time   float64
# 4   std_score_time   float64

# %% [markdown]
# #### Categorize Variables with NLP Regex Tagging

# %%
category_tags = {
    '_time': 'runtime',
    'param_': 'model_parameters',
    '_test_': 'score' 
    # Left is Data (including aggregated data) 
    # Right is eval_metric
}

for k, v in category_tags.items():
    performance_dict.loc[performance_dict['var_name'].str.contains(k),
                        'performance_category'] = v

# %%
show_cols = [
    'model_id',
    'framework',
    'features',
    'mean_test_accuracy',
    'mean_test_neg_brier_score',
    'mean_test_roc_auc',
    'mean_test_precision',
    'mean_test_recall',
    'param_booster', 
    'param_objective', 
    'param_eval_metric',
    'param_subsample',
    'param_max_depth', 
    'param_min_child_weight',
    'param_reg_lambda',
    'param_gamma', 
    'param_eta',
]

performance[show_cols].sort_values('mean_test_accuracy', 
                                   ascending = False).round(2).head(200)
# Out:
#       model_id framework   features  mean_test_accuracy  \
# 1241       617   xgboost  no_credit                0.60
# 1365       741   xgboost  no_credit                0.60
# 1219       595   xgboost  no_credit                0.60
# 1217       593   xgboost  no_credit                0.60
# 1337       713   xgboost  no_credit                0.60
# 1339       715   xgboost  no_credit                0.60
# 1341       717   xgboost  no_credit                0.60
# 1343       719   xgboost  no_credit                0.60
# 1361       737   xgboost  no_credit                0.60
# 1363       739   xgboost  no_credit                0.60
# 1367       743   xgboost  no_credit                0.60
# 1315       691   xgboost  no_credit                0.60
# 1385       761   xgboost  no_credit                0.60
# 1387       763   xgboost  no_credit                0.60
# 1389       765   xgboost  no_credit                0.60
# 1391       767   xgboost  no_credit                0.60
# 1409       785   xgboost  no_credit                0.60
# 1411       787   xgboost  no_credit                0.60
# 1413       789   xgboost  no_credit                0.60
# 1415       791   xgboost  no_credit                0.60
# 1317       693   xgboost  no_credit                0.60
# 1319       695   xgboost  no_credit                0.60
# 1313       689   xgboost  no_credit                0.60
# 1289       665   xgboost  no_credit                0.60
# 1243       619   xgboost  no_credit                0.60
# 1245       621   xgboost  no_credit                0.60
# 1247       623   xgboost  no_credit                0.60
# 1265       641   xgboost  no_credit                0.60
# 1267       643   xgboost  no_credit                0.60
# 1269       645   xgboost  no_credit                0.60
# 1271       647   xgboost  no_credit                0.60
# 1291       667   xgboost  no_credit                0.60
# 1293       669   xgboost  no_credit                0.60
# 1295       671   xgboost  no_credit                0.60
# 1223       599   xgboost  no_credit                0.60
# 1221       597   xgboost  no_credit                0.60
# 580        148   xgboost  no_credit                0.60
# 577        145   xgboost  no_credit                0.60
# 586        154   xgboost  no_credit                0.60
# 583        151   xgboost  no_credit                0.60
# 535        103   xgboost  no_credit                0.59
# 1475       851   xgboost  no_credit                0.59
# 1453       829   xgboost  no_credit                0.59
# 1473       849   xgboost  no_credit                0.59
# 532        100   xgboost  no_credit                0.59
# 529         97   xgboost  no_credit                0.59
# 1215       591   xgboost  no_credit                0.59
# 1451       827   xgboost  no_credit                0.59
# 1449       825   xgboost  no_credit                0.59
# 1359       735   xgboost  no_credit                0.59
# 538        106   xgboost  no_credit                0.59
# 1287       663   xgboost  no_credit                0.59
# 1477       853   xgboost  no_credit                0.59
# 584        152   xgboost  no_credit                0.59
# 581        149   xgboost  no_credit                0.59
# 587        155   xgboost  no_credit                0.59
# 578        146   xgboost  no_credit                0.59
# 1211       587   xgboost  no_credit                0.58
# 1353       729   xgboost  no_credit                0.58
# 1281       657   xgboost  no_credit                0.58
# 1285       661   xgboost  no_credit                0.58
# 1283       659   xgboost  no_credit                0.58
# 1355       731   xgboost  no_credit                0.58
# 1357       733   xgboost  no_credit                0.58
# 1213       589   xgboost  no_credit                0.58
# 1209       585   xgboost  no_credit                0.58
# 482         50   xgboost  no_credit                0.58
# 443         11   xgboost  no_credit                0.58
# 440          8   xgboost  no_credit                0.58
# 437          5   xgboost  no_credit                0.58
# 434          2   xgboost  no_credit                0.58
# 485         53   xgboost  no_credit                0.58
# 491         59   xgboost  no_credit                0.58
# 488         56   xgboost  no_credit                0.58
# 9            9   xgboost  no_credit                0.58
# 11          11   xgboost  no_credit                0.58
# 45          45   xgboost  no_credit                0.58
# 47          47   xgboost  no_credit                0.58
# 1479       855   xgboost  no_credit                0.58
# 1455       831   xgboost  no_credit                0.58
# 539        107   xgboost  no_credit                0.58
# 530         98   xgboost  no_credit                0.58
# 533        101   xgboost  no_credit                0.58
# 536        104   xgboost  no_credit                0.58
# 81          81   xgboost  no_credit                0.57
# 429        429   xgboost  no_credit                0.57
# 83          83   xgboost  no_credit                0.57
# 417        417   xgboost  no_credit                0.57
# 1427       803   xgboost  no_credit                0.57
# 1425       801   xgboost  no_credit                0.57
# 1429       805   xgboost  no_credit                0.57
# 1431       807   xgboost  no_credit                0.57
# 297        297   xgboost  no_credit                0.57
# 590        158   xgboost  no_credit                0.57
# 93          93   xgboost  no_credit                0.57
# 599        167   xgboost  no_credit                0.57
# 1378       754   xgboost  no_credit                0.57
# 1402       778   xgboost  no_credit                0.57
# 593        161   xgboost  no_credit                0.57
# 596        164   xgboost  no_credit                0.57
# 105        105   xgboost  no_credit                0.57
# 1304       680   xgboost  no_credit                0.57
# 1328       704   xgboost  no_credit                0.57
# 1457       833   xgboost  no_credit                0.57
# 1483       859   xgboost  no_credit                0.57
# 1485       861   xgboost  no_credit                0.57
# 1376       752   xgboost  no_credit                0.57
# 1400       776   xgboost  no_credit                0.57
# 1487       863   xgboost  no_credit                0.57
# 1433       809   xgboost  no_credit                0.57
# 1439       815   xgboost  no_credit                0.57
# 1435       811   xgboost  no_credit                0.57
# 1437       813   xgboost  no_credit                0.57
# 1459       835   xgboost  no_credit                0.57
# 1461       837   xgboost  no_credit                0.57
# 1463       839   xgboost  no_credit                0.57
# 1481       857   xgboost  no_credit                0.57
# 1330       706   xgboost  no_credit                0.57
# 1234       610   xgboost  no_credit                0.57
# 1258       634   xgboost  no_credit                0.57
# 95          95   xgboost  no_credit                0.57
# 1306       682   xgboost  no_credit                0.57
# 107        107   xgboost  no_credit                0.57
# 1316       692   xgboost  no_credit                0.57
# 1318       694   xgboost  no_credit                0.57
# 1266       642   xgboost  no_credit                0.57
# 1388       764   xgboost  no_credit                0.57
# 1386       762   xgboost  no_credit                0.57
# 1242       618   xgboost  no_credit                0.57
# 1232       608   xgboost  no_credit                0.57
# 1380       756   xgboost  no_credit                0.57
# 1268       644   xgboost  no_credit                0.57
# 1292       668   xgboost  no_credit                0.57
# 1290       666   xgboost  no_credit                0.57
# 1366       742   xgboost  no_credit                0.57
# 1364       740   xgboost  no_credit                0.57
# 1222       598   xgboost  no_credit                0.57
# 1362       738   xgboost  no_credit                0.57
# 1244       620   xgboost  no_credit                0.57
# 1270       646   xgboost  no_credit                0.57
# 1390       766   xgboost  no_credit                0.57
# 1220       596   xgboost  no_credit                0.57
# 1294       670   xgboost  no_credit                0.57
# 1256       632   xgboost  no_credit                0.57
# 1340       716   xgboost  no_credit                0.57
# 1338       714   xgboost  no_credit                0.57
# 1314       690   xgboost  no_credit                0.57
# 1218       594   xgboost  no_credit                0.57
# 1246       622   xgboost  no_credit                0.57
# 1342       718   xgboost  no_credit                0.57
# 1404       780   xgboost  no_credit                0.57
# 1414       790   xgboost  no_credit                0.57
# 1412       788   xgboost  no_credit                0.57
# 1410       786   xgboost  no_credit                0.57
# 1262       638   xgboost  no_credit                0.57
# 1346       722   xgboost  no_credit                0.57
# 1344       720   xgboost  no_credit                0.57
# 191        191   xgboost  no_credit                0.57
# 1202       578   xgboost  no_credit                0.57
# 1200       576   xgboost  no_credit                0.57
# 1360       736   xgboost  no_credit                0.57
# 1334       710   xgboost  no_credit                0.57
# 1408       784   xgboost  no_credit                0.57
# 1332       708   xgboost  no_credit                0.57
# 1464       840   xgboost  no_credit                0.57
# 1260       636   xgboost  no_credit                0.57
# 189        189   xgboost  no_credit                0.57
# 1382       758   xgboost  no_credit                0.57
# 1440       816   xgboost  no_credit                0.57
# 1310       686   xgboost  no_credit                0.57
# 1406       782   xgboost  no_credit                0.57
# 1308       684   xgboost  no_credit                0.57
# 1238       614   xgboost  no_credit                0.57
# 1272       648   xgboost  no_credit                0.57
# 1274       650   xgboost  no_credit                0.57
# 1236       612   xgboost  no_credit                0.57
# 1384       760   xgboost  no_credit                0.57
# 1264       640   xgboost  no_credit                0.56
# 1288       664   xgboost  no_credit                0.56
# 1312       688   xgboost  no_credit                0.56
# 1336       712   xgboost  no_credit                0.56
# 201        201   xgboost  no_credit                0.56
# 213        213   xgboost  no_credit                0.56
# 1252       628   xgboost  no_credit                0.56
# 1216       592   xgboost  no_credit                0.56
# 1240       616   xgboost  no_credit                0.56
# 1324       700   xgboost  no_credit                0.56
# 323        323   xgboost  no_credit                0.56
# 311        311   xgboost  no_credit                0.56
# 1348       724   xgboost  no_credit                0.56
# 595        163   xgboost  no_credit                0.56
# 598        166   xgboost  no_credit                0.56
# 1170       546   xgboost  no_credit                0.56
# 1194       570   xgboost  no_credit                0.56
# 544        112   xgboost  no_credit                0.56
# 1204       580   xgboost  no_credit                0.56
# 592        160   xgboost  no_credit                0.56
# 1146       522   xgboost  no_credit                0.56
# 550        118   xgboost  no_credit                0.56
# 589        157   xgboost  no_credit                0.56
#
#       mean_test_neg_brier_score  mean_test_roc_auc  mean_test_precision  \
# 1241                      -0.25               0.56                 0.60
# 1365                      -0.25               0.57                 0.60
# 1219                      -0.25               0.57                 0.60
# 1217                      -0.25               0.56                 0.60
# 1337                      -0.25               0.56                 0.60
# 1339                      -0.25               0.57                 0.60
# 1341                      -0.25               0.57                 0.60
# 1343                      -0.25               0.56                 0.60
# 1361                      -0.25               0.56                 0.60
# 1363                      -0.25               0.57                 0.60
# 1367                      -0.25               0.56                 0.60
# 1315                      -0.25               0.57                 0.60
# 1385                      -0.25               0.56                 0.60
# 1387                      -0.25               0.57                 0.60
# 1389                      -0.25               0.57                 0.60
# 1391                      -0.25               0.56                 0.60
# 1409                      -0.25               0.56                 0.60
# 1411                      -0.25               0.57                 0.60
# 1413                      -0.25               0.57                 0.60
# 1415                      -0.25               0.56                 0.60
# 1317                      -0.25               0.57                 0.60
# 1319                      -0.25               0.56                 0.60
# 1313                      -0.25               0.56                 0.60
# 1289                      -0.25               0.56                 0.60
# 1243                      -0.25               0.57                 0.60
# 1245                      -0.25               0.57                 0.60
# 1247                      -0.25               0.56                 0.60
# 1265                      -0.25               0.56                 0.60
# 1267                      -0.25               0.57                 0.60
# 1269                      -0.25               0.57                 0.60
# 1271                      -0.25               0.56                 0.60
# 1291                      -0.25               0.57                 0.60
# 1293                      -0.25               0.57                 0.60
# 1295                      -0.25               0.56                 0.60
# 1223                      -0.25               0.56                 0.60
# 1221                      -0.25               0.57                 0.60
# 580                       -0.25               0.61                 0.60
# 577                       -0.25               0.61                 0.60
# 586                       -0.25               0.61                 0.60
# 583                       -0.25               0.61                 0.60
# 535                       -0.25               0.60                 0.60
# 1475                      -0.25               0.58                 0.60
# 1453                      -0.25               0.58                 0.60
# 1473                      -0.25               0.58                 0.60
# 532                       -0.25               0.60                 0.60
# 529                       -0.25               0.60                 0.60
# 1215                      -0.25               0.55                 0.59
# 1451                      -0.25               0.58                 0.60
# 1449                      -0.25               0.58                 0.60
# 1359                      -0.25               0.55                 0.59
# 538                       -0.25               0.60                 0.60
# 1287                      -0.25               0.55                 0.59
# 1477                      -0.25               0.58                 0.60
# 584                       -0.25               0.58                 0.63
# 581                       -0.25               0.58                 0.63
# 587                       -0.25               0.58                 0.63
# 578                       -0.25               0.58                 0.63
# 1211                      -0.25               0.57                 0.60
# 1353                      -0.25               0.57                 0.60
# 1281                      -0.25               0.57                 0.60
# 1285                      -0.25               0.55                 0.60
# 1283                      -0.25               0.57                 0.60
# 1355                      -0.25               0.57                 0.60
# 1357                      -0.25               0.55                 0.60
# 1213                      -0.25               0.55                 0.60
# 1209                      -0.25               0.57                 0.60
# 482                       -0.24               0.58                 0.61
# 443                       -0.25               0.56                 0.60
# 440                       -0.25               0.56                 0.60
# 437                       -0.25               0.56                 0.60
# 434                       -0.25               0.56                 0.60
# 485                       -0.24               0.58                 0.61
# 491                       -0.24               0.58                 0.61
# 488                       -0.24               0.58                 0.61
# 9                         -0.25               0.55                 0.60
# 11                        -0.25               0.55                 0.60
# 45                        -0.25               0.55                 0.60
# 47                        -0.25               0.55                 0.60
# 1479                      -0.25               0.59                 0.60
# 1455                      -0.25               0.59                 0.60
# 539                       -0.25               0.58                 0.62
# 530                       -0.25               0.58                 0.62
# 533                       -0.25               0.58                 0.62
# 536                       -0.25               0.58                 0.62
# 81                        -0.25               0.55                 0.59
# 429                       -0.25               0.55                 0.59
# 83                        -0.25               0.55                 0.59
# 417                       -0.25               0.55                 0.59
# 1427                      -0.25               0.59                 0.59
# 1425                      -0.25               0.59                 0.59
# 1429                      -0.25               0.59                 0.59
# 1431                      -0.25               0.59                 0.59
# 297                       -0.25               0.52                 0.59
# 590                       -0.25               0.56                 0.61
# 93                        -0.25               0.53                 0.59
# 599                       -0.25               0.56                 0.61
# 1378                      -0.25               0.56                 0.59
# 1402                      -0.25               0.56                 0.59
# 593                       -0.25               0.56                 0.61
# 596                       -0.25               0.56                 0.61
# 105                       -0.25               0.53                 0.59
# 1304                      -0.25               0.56                 0.59
# 1328                      -0.25               0.56                 0.59
# 1457                      -0.25               0.58                 0.60
# 1483                      -0.25               0.58                 0.60
# 1485                      -0.25               0.58                 0.60
# 1376                      -0.25               0.56                 0.59
# 1400                      -0.25               0.56                 0.59
# 1487                      -0.25               0.58                 0.60
# 1433                      -0.25               0.58                 0.60
# 1439                      -0.25               0.58                 0.60
# 1435                      -0.25               0.58                 0.60
# 1437                      -0.25               0.58                 0.60
# 1459                      -0.25               0.58                 0.60
# 1461                      -0.25               0.58                 0.60
# 1463                      -0.25               0.58                 0.60
# 1481                      -0.25               0.58                 0.60
# 1330                      -0.25               0.56                 0.59
# 1234                      -0.25               0.56                 0.59
# 1258                      -0.25               0.56                 0.59
# 95                        -0.25               0.54                 0.59
# 1306                      -0.25               0.56                 0.59
# 107                       -0.25               0.54                 0.59
# 1316                      -0.25               0.56                 0.60
# 1318                      -0.25               0.56                 0.60
# 1266                      -0.25               0.56                 0.60
# 1388                      -0.25               0.56                 0.60
# 1386                      -0.25               0.56                 0.60
# 1242                      -0.25               0.56                 0.60
# 1232                      -0.25               0.56                 0.59
# 1380                      -0.25               0.56                 0.59
# 1268                      -0.25               0.56                 0.60
# 1292                      -0.25               0.56                 0.60
# 1290                      -0.25               0.56                 0.60
# 1366                      -0.25               0.56                 0.60
# 1364                      -0.25               0.56                 0.60
# 1222                      -0.25               0.56                 0.60
# 1362                      -0.25               0.56                 0.60
# 1244                      -0.25               0.56                 0.60
# 1270                      -0.25               0.56                 0.60
# 1390                      -0.25               0.56                 0.60
# 1220                      -0.25               0.56                 0.60
# 1294                      -0.25               0.56                 0.60
# 1256                      -0.25               0.56                 0.59
# 1340                      -0.25               0.56                 0.60
# 1338                      -0.25               0.56                 0.60
# 1314                      -0.25               0.56                 0.60
# 1218                      -0.25               0.56                 0.60
# 1246                      -0.25               0.56                 0.60
# 1342                      -0.25               0.56                 0.60
# 1404                      -0.25               0.56                 0.59
# 1414                      -0.25               0.56                 0.60
# 1412                      -0.25               0.56                 0.60
# 1410                      -0.25               0.56                 0.60
# 1262                      -0.25               0.56                 0.59
# 1346                      -0.25               0.56                 0.58
# 1344                      -0.25               0.56                 0.58
# 191                       -0.25               0.55                 0.57
# 1202                      -0.25               0.56                 0.58
# 1200                      -0.25               0.56                 0.58
# 1360                      -0.25               0.56                 0.60
# 1334                      -0.25               0.56                 0.59
# 1408                      -0.25               0.56                 0.60
# 1332                      -0.25               0.56                 0.59
# 1464                      -0.25               0.54                 0.58
# 1260                      -0.25               0.56                 0.59
# 189                       -0.25               0.55                 0.57
# 1382                      -0.25               0.56                 0.59
# 1440                      -0.25               0.54                 0.58
# 1310                      -0.25               0.56                 0.59
# 1406                      -0.25               0.56                 0.59
# 1308                      -0.25               0.56                 0.59
# 1238                      -0.25               0.56                 0.59
# 1272                      -0.25               0.56                 0.58
# 1274                      -0.25               0.56                 0.58
# 1236                      -0.25               0.56                 0.59
# 1384                      -0.25               0.56                 0.60
# 1264                      -0.25               0.56                 0.60
# 1288                      -0.25               0.56                 0.60
# 1312                      -0.25               0.56                 0.60
# 1336                      -0.25               0.56                 0.60
# 201                       -0.25               0.53                 0.58
# 213                       -0.25               0.53                 0.58
# 1252                      -0.25               0.54                 0.60
# 1216                      -0.25               0.56                 0.60
# 1240                      -0.25               0.56                 0.60
# 1324                      -0.25               0.54                 0.60
# 323                       -0.25               0.53                 0.59
# 311                       -0.25               0.53                 0.59
# 1348                      -0.25               0.56                 0.58
# 595                       -0.25               0.56                 0.59
# 598                       -0.25               0.56                 0.59
# 1170                      -0.25               0.53                 0.58
# 1194                      -0.25               0.53                 0.58
# 544                       -0.25               0.56                 0.59
# 1204                      -0.25               0.56                 0.58
# 592                       -0.25               0.56                 0.59
# 1146                      -0.25               0.53                 0.58
# 550                       -0.25               0.56                 0.59
# 589                       -0.25               0.56                 0.59
#
#       mean_test_recall param_booster  param_objective param_eval_metric  \
# 1241              0.82        gbtree  binary:logistic           logloss
# 1365              0.82        gbtree  binary:logistic           logloss
# 1219              0.82        gbtree  binary:logistic           logloss
# 1217              0.82        gbtree  binary:logistic           logloss
# 1337              0.82        gbtree  binary:logistic           logloss
# 1339              0.82        gbtree  binary:logistic           logloss
# 1341              0.82        gbtree  binary:logistic           logloss
# 1343              0.82        gbtree  binary:logistic           logloss
# 1361              0.82        gbtree  binary:logistic           logloss
# 1363              0.82        gbtree  binary:logistic           logloss
# 1367              0.82        gbtree  binary:logistic           logloss
# 1315              0.82        gbtree  binary:logistic           logloss
# 1385              0.82        gbtree  binary:logistic           logloss
# 1387              0.82        gbtree  binary:logistic           logloss
# 1389              0.82        gbtree  binary:logistic           logloss
# 1391              0.82        gbtree  binary:logistic           logloss
# 1409              0.82        gbtree  binary:logistic           logloss
# 1411              0.82        gbtree  binary:logistic           logloss
# 1413              0.82        gbtree  binary:logistic           logloss
# 1415              0.82        gbtree  binary:logistic           logloss
# 1317              0.82        gbtree  binary:logistic           logloss
# 1319              0.82        gbtree  binary:logistic           logloss
# 1313              0.82        gbtree  binary:logistic           logloss
# 1289              0.82        gbtree  binary:logistic           logloss
# 1243              0.82        gbtree  binary:logistic           logloss
# 1245              0.82        gbtree  binary:logistic           logloss
# 1247              0.82        gbtree  binary:logistic           logloss
# 1265              0.82        gbtree  binary:logistic           logloss
# 1267              0.82        gbtree  binary:logistic           logloss
# 1269              0.82        gbtree  binary:logistic           logloss
# 1271              0.82        gbtree  binary:logistic           logloss
# 1291              0.82        gbtree  binary:logistic           logloss
# 1293              0.82        gbtree  binary:logistic           logloss
# 1295              0.82        gbtree  binary:logistic           logloss
# 1223              0.82        gbtree  binary:logistic           logloss
# 1221              0.82        gbtree  binary:logistic           logloss
# 580               0.82        gbtree  binary:logistic           logloss
# 577               0.82        gbtree  binary:logistic           logloss
# 586               0.82        gbtree  binary:logistic           logloss
# 583               0.82        gbtree  binary:logistic           logloss
# 535               0.79        gbtree  binary:logistic           logloss
# 1475              0.76        gbtree  binary:logistic           logloss
# 1453              0.76        gbtree  binary:logistic           logloss
# 1473              0.76        gbtree  binary:logistic           logloss
# 532               0.79        gbtree  binary:logistic           logloss
# 529               0.79        gbtree  binary:logistic           logloss
# 1215              0.85        gbtree  binary:logistic           logloss
# 1451              0.76        gbtree  binary:logistic           logloss
# 1449              0.76        gbtree  binary:logistic           logloss
# 1359              0.85        gbtree  binary:logistic           logloss
# 538               0.79        gbtree  binary:logistic           logloss
# 1287              0.85        gbtree  binary:logistic           logloss
# 1477              0.76        gbtree  binary:logistic           logloss
# 584               0.60        gbtree  binary:logistic           logloss
# 581               0.60        gbtree  binary:logistic           logloss
# 587               0.60        gbtree  binary:logistic           logloss
# 578               0.60        gbtree  binary:logistic           logloss
# 1211              0.80        gbtree  binary:logistic           logloss
# 1353              0.80        gbtree  binary:logistic           logloss
# 1281              0.80        gbtree  binary:logistic           logloss
# 1285              0.80        gbtree  binary:logistic           logloss
# 1283              0.80        gbtree  binary:logistic           logloss
# 1355              0.80        gbtree  binary:logistic           logloss
# 1357              0.80        gbtree  binary:logistic           logloss
# 1213              0.80        gbtree  binary:logistic           logloss
# 1209              0.80        gbtree  binary:logistic           logloss
# 482               0.68        gbtree  binary:logistic           logloss
# 443               0.76        gbtree  binary:logistic           logloss
# 440               0.76        gbtree  binary:logistic           logloss
# 437               0.76        gbtree  binary:logistic           logloss
# 434               0.76        gbtree  binary:logistic           logloss
# 485               0.68        gbtree  binary:logistic           logloss
# 491               0.68        gbtree  binary:logistic           logloss
# 488               0.68        gbtree  binary:logistic           logloss
# 9                 0.77        gbtree  binary:logistic           logloss
# 11                0.76        gbtree  binary:logistic           logloss
# 45                0.77        gbtree  binary:logistic           logloss
# 47                0.76        gbtree  binary:logistic           logloss
# 1479              0.72        gbtree  binary:logistic           logloss
# 1455              0.72        gbtree  binary:logistic           logloss
# 539               0.63        gbtree  binary:logistic           logloss
# 530               0.63        gbtree  binary:logistic           logloss
# 533               0.63        gbtree  binary:logistic           logloss
# 536               0.63        gbtree  binary:logistic           logloss
# 81                0.78        gbtree  binary:logistic           logloss
# 429               0.80        gbtree  binary:logistic           logloss
# 83                0.78        gbtree  binary:logistic           logloss
# 417               0.80        gbtree  binary:logistic           logloss
# 1427              0.77        gbtree  binary:logistic           logloss
# 1425              0.77        gbtree  binary:logistic           logloss
# 1429              0.77        gbtree  binary:logistic           logloss
# 1431              0.77        gbtree  binary:logistic           logloss
# 297               0.82        gbtree  binary:logistic           logloss
# 590               0.66        gbtree  binary:logistic           logloss
# 93                0.77        gbtree  binary:logistic           logloss
# 599               0.66        gbtree  binary:logistic           logloss
# 1378              0.75        gbtree  binary:logistic           logloss
# 1402              0.75        gbtree  binary:logistic           logloss
# 593               0.66        gbtree  binary:logistic           logloss
# 596               0.66        gbtree  binary:logistic           logloss
# 105               0.77        gbtree  binary:logistic           logloss
# 1304              0.75        gbtree  binary:logistic           logloss
# 1328              0.75        gbtree  binary:logistic           logloss
# 1457              0.68        gbtree  binary:logistic           logloss
# 1483              0.68        gbtree  binary:logistic           logloss
# 1485              0.68        gbtree  binary:logistic           logloss
# 1376              0.76        gbtree  binary:logistic           logloss
# 1400              0.76        gbtree  binary:logistic           logloss
# 1487              0.68        gbtree  binary:logistic           logloss
# 1433              0.68        gbtree  binary:logistic           logloss
# 1439              0.68        gbtree  binary:logistic           logloss
# 1435              0.68        gbtree  binary:logistic           logloss
# 1437              0.68        gbtree  binary:logistic           logloss
# 1459              0.68        gbtree  binary:logistic           logloss
# 1461              0.68        gbtree  binary:logistic           logloss
# 1463              0.68        gbtree  binary:logistic           logloss
# 1481              0.68        gbtree  binary:logistic           logloss
# 1330              0.75        gbtree  binary:logistic           logloss
# 1234              0.75        gbtree  binary:logistic           logloss
# 1258              0.75        gbtree  binary:logistic           logloss
# 95                0.78        gbtree  binary:logistic           logloss
# 1306              0.75        gbtree  binary:logistic           logloss
# 107               0.78        gbtree  binary:logistic           logloss
# 1316              0.67        gbtree  binary:logistic           logloss
# 1318              0.67        gbtree  binary:logistic           logloss
# 1266              0.67        gbtree  binary:logistic           logloss
# 1388              0.67        gbtree  binary:logistic           logloss
# 1386              0.67        gbtree  binary:logistic           logloss
# 1242              0.67        gbtree  binary:logistic           logloss
# 1232              0.75        gbtree  binary:logistic           logloss
# 1380              0.75        gbtree  binary:logistic           logloss
# 1268              0.67        gbtree  binary:logistic           logloss
# 1292              0.67        gbtree  binary:logistic           logloss
# 1290              0.67        gbtree  binary:logistic           logloss
# 1366              0.67        gbtree  binary:logistic           logloss
# 1364              0.67        gbtree  binary:logistic           logloss
# 1222              0.67        gbtree  binary:logistic           logloss
# 1362              0.67        gbtree  binary:logistic           logloss
# 1244              0.67        gbtree  binary:logistic           logloss
# 1270              0.67        gbtree  binary:logistic           logloss
# 1390              0.67        gbtree  binary:logistic           logloss
# 1220              0.67        gbtree  binary:logistic           logloss
# 1294              0.67        gbtree  binary:logistic           logloss
# 1256              0.75        gbtree  binary:logistic           logloss
# 1340              0.67        gbtree  binary:logistic           logloss
# 1338              0.67        gbtree  binary:logistic           logloss
# 1314              0.67        gbtree  binary:logistic           logloss
# 1218              0.67        gbtree  binary:logistic           logloss
# 1246              0.67        gbtree  binary:logistic           logloss
# 1342              0.67        gbtree  binary:logistic           logloss
# 1404              0.75        gbtree  binary:logistic           logloss
# 1414              0.67        gbtree  binary:logistic           logloss
# 1412              0.67        gbtree  binary:logistic           logloss
# 1410              0.67        gbtree  binary:logistic           logloss
# 1262              0.75        gbtree  binary:logistic           logloss
# 1346              0.77        gbtree  binary:logistic           logloss
# 1344              0.77        gbtree  binary:logistic           logloss
# 191               0.86        gbtree  binary:logistic           logloss
# 1202              0.77        gbtree  binary:logistic           logloss
# 1200              0.77        gbtree  binary:logistic           logloss
# 1360              0.67        gbtree  binary:logistic           logloss
# 1334              0.75        gbtree  binary:logistic           logloss
# 1408              0.67        gbtree  binary:logistic           logloss
# 1332              0.75        gbtree  binary:logistic           logloss
# 1464              0.80        gbtree  binary:logistic           logloss
# 1260              0.75        gbtree  binary:logistic           logloss
# 189               0.86        gbtree  binary:logistic           logloss
# 1382              0.75        gbtree  binary:logistic           logloss
# 1440              0.80        gbtree  binary:logistic           logloss
# 1310              0.75        gbtree  binary:logistic           logloss
# 1406              0.75        gbtree  binary:logistic           logloss
# 1308              0.75        gbtree  binary:logistic           logloss
# 1238              0.75        gbtree  binary:logistic           logloss
# 1272              0.77        gbtree  binary:logistic           logloss
# 1274              0.77        gbtree  binary:logistic           logloss
# 1236              0.75        gbtree  binary:logistic           logloss
# 1384              0.67        gbtree  binary:logistic           logloss
# 1264              0.67        gbtree  binary:logistic           logloss
# 1288              0.67        gbtree  binary:logistic           logloss
# 1312              0.67        gbtree  binary:logistic           logloss
# 1336              0.67        gbtree  binary:logistic           logloss
# 201               0.82        gbtree  binary:logistic           logloss
# 213               0.82        gbtree  binary:logistic           logloss
# 1252              0.71        gbtree  binary:logistic           logloss
# 1216              0.67        gbtree  binary:logistic           logloss
# 1240              0.67        gbtree  binary:logistic           logloss
# 1324              0.71        gbtree  binary:logistic           logloss
# 323               0.77        gbtree  binary:logistic           logloss
# 311               0.77        gbtree  binary:logistic           logloss
# 1348              0.77        gbtree  binary:logistic           logloss
# 595               0.71        gbtree  binary:logistic           logloss
# 598               0.71        gbtree  binary:logistic           logloss
# 1170              0.84        gbtree  binary:logistic           logloss
# 1194              0.84        gbtree  binary:logistic           logloss
# 544               0.71        gbtree  binary:logistic           logloss
# 1204              0.77        gbtree  binary:logistic           logloss
# 592               0.71        gbtree  binary:logistic           logloss
# 1146              0.84        gbtree  binary:logistic           logloss
# 550               0.71        gbtree  binary:logistic           logloss
# 589               0.71        gbtree  binary:logistic           logloss
#
#      param_subsample param_max_depth param_min_child_weight param_reg_lambda  \
# 1241               1               4                     20                0
# 1365               1               2                     20                1
# 1219               1               2                     20              0.5
# 1217               1               2                     20                0
# 1337               1               8                     20                0
# 1339               1               8                     20              0.5
# 1341               1               8                     20                1
# 1343               1               8                     20              1.5
# 1361               1               2                     20                0
# 1363               1               2                     20              0.5
# 1367               1               2                     20              1.5
# 1315               1               4                     20              0.5
# 1385               1               4                     20                0
# 1387               1               4                     20              0.5
# 1389               1               4                     20                1
# 1391               1               4                     20              1.5
# 1409               1               8                     20                0
# 1411               1               8                     20              0.5
# 1413               1               8                     20                1
# 1415               1               8                     20              1.5
# 1317               1               4                     20                1
# 1319               1               4                     20              1.5
# 1313               1               4                     20                0
# 1289               1               2                     20                0
# 1243               1               4                     20              0.5
# 1245               1               4                     20                1
# 1247               1               4                     20              1.5
# 1265               1               8                     20                0
# 1267               1               8                     20              0.5
# 1269               1               8                     20                1
# 1271               1               8                     20              1.5
# 1291               1               2                     20              0.5
# 1293               1               2                     20                1
# 1295               1               2                     20              1.5
# 1223               1               2                     20              1.5
# 1221               1               2                     20                1
# 580              NaN               8                     24              NaN
# 577              NaN               4                     24              NaN
# 586              NaN              32                     24              NaN
# 583              NaN              16                     24              NaN
# 535              NaN              16                     24              NaN
# 1475               1               8                     12              0.5
# 1453               1               4                     12                1
# 1473               1               8                     12                0
# 532              NaN               8                     24              NaN
# 529              NaN               4                     24              NaN
# 1215               1               2                     12              1.5
# 1451               1               4                     12              0.5
# 1449               1               4                     12                0
# 1359               1               2                     12              1.5
# 538              NaN              32                     24              NaN
# 1287               1               2                     12              1.5
# 1477               1               8                     12                1
# 584              NaN              16                     48              NaN
# 581              NaN               8                     48              NaN
# 587              NaN              32                     48              NaN
# 578              NaN               4                     48              NaN
# 1211               1               2                     12              0.5
# 1353               1               2                     12                0
# 1281               1               2                     12                0
# 1285               1               2                     12                1
# 1283               1               2                     12              0.5
# 1355               1               2                     12              0.5
# 1357               1               2                     12                1
# 1213               1               2                     12                1
# 1209               1               2                     12                0
# 482              NaN               4                     48              NaN
# 443              NaN              32                     48              NaN
# 440              NaN              16                     48              NaN
# 437              NaN               8                     48              NaN
# 434              NaN               4                     48              NaN
# 485              NaN               8                     48              NaN
# 491              NaN              32                     48              NaN
# 488              NaN              16                     48              NaN
# 9                  1               2                     16                0
# 11                 1               2                     16                1
# 45                 1               2                     16                0
# 47                 1               2                     16                1
# 1479               1               8                     12              1.5
# 1455               1               4                     12              1.5
# 539              NaN              32                     48              NaN
# 530              NaN               4                     48              NaN
# 533              NaN               8                     48              NaN
# 536              NaN              16                     48              NaN
# 81                 1               2                     16                0
# 429                1               8                     16                0
# 83                 1               2                     16                1
# 417                1               4                     16                0
# 1427               1               2                     12              0.5
# 1425               1               2                     12                0
# 1429               1               2                     12                1
# 1431               1               2                     12              1.5
# 297                1               2                     16                0
# 590              NaN               4                     48              NaN
# 93                 1               4                     16                0
# 599              NaN              32                     48              NaN
# 1378             0.7               4                     12              0.5
# 1402             0.7               8                     12              0.5
# 593              NaN               8                     48              NaN
# 596              NaN              16                     48              NaN
# 105                1               8                     16                0
# 1304             0.7               4                     12                0
# 1328             0.7               8                     12                0
# 1457               1               4                     20                0
# 1483               1               8                     20              0.5
# 1485               1               8                     20                1
# 1376             0.7               4                     12                0
# 1400             0.7               8                     12                0
# 1487               1               8                     20              1.5
# 1433               1               2                     20                0
# 1439               1               2                     20              1.5
# 1435               1               2                     20              0.5
# 1437               1               2                     20                1
# 1459               1               4                     20              0.5
# 1461               1               4                     20                1
# 1463               1               4                     20              1.5
# 1481               1               8                     20                0
# 1330             0.7               8                     12              0.5
# 1234             0.7               4                     12              0.5
# 1258             0.7               8                     12              0.5
# 95                 1               4                     16                1
# 1306             0.7               4                     12              0.5
# 107                1               8                     16                1
# 1316             0.7               4                     20                1
# 1318             0.7               4                     20              1.5
# 1266             0.7               8                     20              0.5
# 1388             0.7               4                     20                1
# 1386             0.7               4                     20              0.5
# 1242             0.7               4                     20              0.5
# 1232             0.7               4                     12                0
# 1380             0.7               4                     12                1
# 1268             0.7               8                     20                1
# 1292             0.7               2                     20                1
# 1290             0.7               2                     20              0.5
# 1366             0.7               2                     20              1.5
# 1364             0.7               2                     20                1
# 1222             0.7               2                     20              1.5
# 1362             0.7               2                     20              0.5
# 1244             0.7               4                     20                1
# 1270             0.7               8                     20              1.5
# 1390             0.7               4                     20              1.5
# 1220             0.7               2                     20                1
# 1294             0.7               2                     20              1.5
# 1256             0.7               8                     12                0
# 1340             0.7               8                     20                1
# 1338             0.7               8                     20              0.5
# 1314             0.7               4                     20              0.5
# 1218             0.7               2                     20              0.5
# 1246             0.7               4                     20              1.5
# 1342             0.7               8                     20              1.5
# 1404             0.7               8                     12                1
# 1414             0.7               8                     20              1.5
# 1412             0.7               8                     20                1
# 1410             0.7               8                     20              0.5
# 1262             0.7               8                     12              1.5
# 1346             0.7               2                      8              0.5
# 1344             0.7               2                      8                0
# 191                1               2                     16                1
# 1202             0.7               2                      8              0.5
# 1200             0.7               2                      8                0
# 1360             0.7               2                     20                0
# 1334             0.7               8                     12              1.5
# 1408             0.7               8                     20                0
# 1332             0.7               8                     12                1
# 1464             0.7               8                      8                0
# 1260             0.7               8                     12                1
# 189                1               2                     16                0
# 1382             0.7               4                     12              1.5
# 1440             0.7               4                      8                0
# 1310             0.7               4                     12              1.5
# 1406             0.7               8                     12              1.5
# 1308             0.7               4                     12                1
# 1238             0.7               4                     12              1.5
# 1272             0.7               2                      8                0
# 1274             0.7               2                      8              0.5
# 1236             0.7               4                     12                1
# 1384             0.7               4                     20                0
# 1264             0.7               8                     20                0
# 1288             0.7               2                     20                0
# 1312             0.7               4                     20                0
# 1336             0.7               8                     20                0
# 201                1               4                     16                0
# 213                1               8                     16                0
# 1252             0.7               8                      8                1
# 1216             0.7               2                     20                0
# 1240             0.7               4                     20                0
# 1324             0.7               8                      8                1
# 323                1               8                     16                1
# 311                1               4                     16                1
# 1348             0.7               2                      8                1
# 595              NaN              16                     24              NaN
# 598              NaN              32                     24              NaN
# 1170             0.7               4                     20              0.5
# 1194             0.7               8                     20              0.5
# 544              NaN               8                     24              NaN
# 1204             0.7               2                      8                1
# 592              NaN               8                     24              NaN
# 1146             0.7               2                     20              0.5
# 550              NaN              32                     24              NaN
# 589              NaN               4                     24              NaN
#
#      param_gamma param_eta
# 1241        0.25    0.0005
# 1365           2    0.0005
# 1219        0.25    0.0005
# 1217        0.25    0.0005
# 1337        0.75    0.0005
# 1339        0.75    0.0005
# 1341        0.75    0.0005
# 1343        0.75    0.0005
# 1361           2    0.0005
# 1363           2    0.0005
# 1367           2    0.0005
# 1315        0.75    0.0005
# 1385           2    0.0005
# 1387           2    0.0005
# 1389           2    0.0005
# 1391           2    0.0005
# 1409           2    0.0005
# 1411           2    0.0005
# 1413           2    0.0005
# 1415           2    0.0005
# 1317        0.75    0.0005
# 1319        0.75    0.0005
# 1313        0.75    0.0005
# 1289        0.75    0.0005
# 1243        0.25    0.0005
# 1245        0.25    0.0005
# 1247        0.25    0.0005
# 1265        0.25    0.0005
# 1267        0.25    0.0005
# 1269        0.25    0.0005
# 1271        0.25    0.0005
# 1291        0.75    0.0005
# 1293        0.75    0.0005
# 1295        0.75    0.0005
# 1223        0.25    0.0005
# 1221        0.25    0.0005
# 580            1    0.0001
# 577            1    0.0001
# 586            1    0.0001
# 583            1    0.0001
# 535            1     0.001
# 1475           8    0.0005
# 1453           8    0.0005
# 1473           8    0.0005
# 532            1     0.001
# 529            1     0.001
# 1215        0.25    0.0005
# 1451           8    0.0005
# 1449           8    0.0005
# 1359           2    0.0005
# 538            1     0.001
# 1287        0.75    0.0005
# 1477           8    0.0005
# 584            1    0.0001
# 581            1    0.0001
# 587            1    0.0001
# 578            1    0.0001
# 1211        0.25    0.0005
# 1353           2    0.0005
# 1281        0.75    0.0005
# 1285        0.75    0.0005
# 1283        0.75    0.0005
# 1355           2    0.0005
# 1357           2    0.0005
# 1213        0.25    0.0005
# 1209        0.25    0.0005
# 482            1      0.01
# 443            1      0.05
# 440            1      0.05
# 437            1      0.05
# 434            1      0.05
# 485            1      0.01
# 491            1      0.01
# 488            1      0.01
# 9              0      0.01
# 11             0      0.01
# 45           0.5      0.01
# 47           0.5      0.01
# 1479           8    0.0005
# 1455           8    0.0005
# 539            1     0.001
# 530            1     0.001
# 533            1     0.001
# 536            1     0.001
# 81             5      0.01
# 429            5       0.5
# 83             5      0.01
# 417            5       0.5
# 1427           8    0.0005
# 1425           8    0.0005
# 1429           8    0.0005
# 1431           8    0.0005
# 297            5      0.25
# 590           10    0.0001
# 93             5      0.01
# 599           10    0.0001
# 1378           2    0.0005
# 1402           2    0.0005
# 593           10    0.0001
# 596           10    0.0001
# 105            5      0.01
# 1304        0.75    0.0005
# 1328        0.75    0.0005
# 1457           8    0.0005
# 1483           8    0.0005
# 1485           8    0.0005
# 1376           2    0.0005
# 1400           2    0.0005
# 1487           8    0.0005
# 1433           8    0.0005
# 1439           8    0.0005
# 1435           8    0.0005
# 1437           8    0.0005
# 1459           8    0.0005
# 1461           8    0.0005
# 1463           8    0.0005
# 1481           8    0.0005
# 1330        0.75    0.0005
# 1234        0.25    0.0005
# 1258        0.25    0.0005
# 95             5      0.01
# 1306        0.75    0.0005
# 107            5      0.01
# 1316        0.75    0.0005
# 1318        0.75    0.0005
# 1266        0.25    0.0005
# 1388           2    0.0005
# 1386           2    0.0005
# 1242        0.25    0.0005
# 1232        0.25    0.0005
# 1380           2    0.0005
# 1268        0.25    0.0005
# 1292        0.75    0.0005
# 1290        0.75    0.0005
# 1366           2    0.0005
# 1364           2    0.0005
# 1222        0.25    0.0005
# 1362           2    0.0005
# 1244        0.25    0.0005
# 1270        0.25    0.0005
# 1390           2    0.0005
# 1220        0.25    0.0005
# 1294        0.75    0.0005
# 1256        0.25    0.0005
# 1340        0.75    0.0005
# 1338        0.75    0.0005
# 1314        0.75    0.0005
# 1218        0.25    0.0005
# 1246        0.25    0.0005
# 1342        0.75    0.0005
# 1404           2    0.0005
# 1414           2    0.0005
# 1412           2    0.0005
# 1410           2    0.0005
# 1262        0.25    0.0005
# 1346           2    0.0005
# 1344           2    0.0005
# 191            5       0.1
# 1202        0.25    0.0005
# 1200        0.25    0.0005
# 1360           2    0.0005
# 1334        0.75    0.0005
# 1408           2    0.0005
# 1332        0.75    0.0005
# 1464           8    0.0005
# 1260        0.25    0.0005
# 189            5       0.1
# 1382           2    0.0005
# 1440           8    0.0005
# 1310        0.75    0.0005
# 1406           2    0.0005
# 1308        0.75    0.0005
# 1238        0.25    0.0005
# 1272        0.75    0.0005
# 1274        0.75    0.0005
# 1236        0.25    0.0005
# 1384           2    0.0005
# 1264        0.25    0.0005
# 1288        0.75    0.0005
# 1312        0.75    0.0005
# 1336        0.75    0.0005
# 201            5       0.1
# 213            5       0.1
# 1252        0.25    0.0005
# 1216        0.25    0.0005
# 1240        0.25    0.0005
# 1324        0.75    0.0005
# 323            5      0.25
# 311            5      0.25
# 1348           2    0.0005
# 595           10    0.0001
# 598           10    0.0001
# 1170           8      0.12
# 1194           8      0.12
# 544           10     0.001
# 1204        0.25    0.0005
# 592           10    0.0001
# 1146           8      0.12
# 550           10     0.001
# 589           10    0.0001

# %% [markdown]
# # Evaluate Hyperparameter Performance

# %%
# Designate Hyperparameters
hypers = ['param_subsample', 
          'param_max_depth', 
          'param_min_child_weight',
          'param_reg_lambda',
          'param_gamma', 
          'param_eta',
          'features']

# %%
def hyper_results(performance: pd.DataFrame, hyper: str):
    """
    Summarizes the effects of each hyperparameter on validation set scoring metrics. 
    
    """
    groupby_dict = {
   
    }
    gb = performance.groupby(hyper).agg({'mean_test_accuracy': 'mean',
                                    'mean_test_neg_brier_score': 'mean',
                                    'mean_test_roc_auc': 'mean',
                                    'mean_test_precision': 'mean',
                                    'mean_test_recall': 'mean'})
    
    
    return gb

# %% [markdown]
# #### Maximum Depth of a Tree
# Increasing the max depth of the tree has little effect on most measures of accuracy. Deeper trees have higher precision and lower recall scores.

# %%
hyper_results(performance, 'param_max_depth')
# Out:
#                  mean_test_accuracy  mean_test_neg_brier_score  \
# param_max_depth
# 2                          0.500253                  -0.291303
# 4                          0.497889                  -0.297518
# 8                          0.497172                  -0.299034
# 16                         0.549625                  -0.250335
# 32                         0.549625                  -0.250335
#
#                  mean_test_roc_auc  mean_test_precision  mean_test_recall
# param_max_depth
# 2                         0.495528             0.515723          0.602740
# 4                         0.490185             0.519327          0.602814
# 8                         0.490251             0.521527          0.599792
# 16                        0.526892             0.544583          0.863717
# 32                        0.526892             0.544583          0.863717

# %% [markdown]
# #### Minimum Sample Size for a New Node
# You can strongly improve performance by increasing the minimum sample size for a new tree leaf. The best models we have use the highest possible min_child_weight value, so we should run more tests to find out if higher weights would be even more performant.

# %%
hyper_results(performance, 'param_min_child_weight')
# Out:
#                         mean_test_accuracy  mean_test_neg_brier_score  \
# param_min_child_weight
# 1                                 0.429267                  -0.382507
# 4                                 0.442680                  -0.351781
# 8                                 0.494558                  -0.291438
# 12                                0.511369                  -0.282249
# 16                                0.507683                  -0.286907
# 20                                0.526037                  -0.269906
# 24                                0.556081                  -0.249014
# 48                                0.560473                  -0.248024
#
#                         mean_test_roc_auc  mean_test_precision  \
# param_min_child_weight
# 1                                0.430664             0.405872
# 4                                0.441843             0.433259
# 8                                0.487769             0.490751
# 12                               0.505722             0.547792
# 16                               0.493611             0.554317
# 20                               0.518438             0.573992
# 24                               0.533624             0.565122
# 48                               0.535644             0.572934
#
#                         mean_test_recall
# param_min_child_weight
# 1                               0.416174
# 4                               0.454999
# 8                               0.592666
# 12                              0.625593
# 16                              0.619279
# 20                              0.675250
# 24                              0.904551
# 48                              0.879839

# %% [markdown]
# #### Minimum Performance Gain for a New Node
# Gamma is good! Raise to 10, 20, and 50 to compare.

# %%
hyper_results(performance, 'param_gamma')
# Out:
#              mean_test_accuracy  mean_test_neg_brier_score  mean_test_roc_auc  \
# param_gamma
# 0.00                   0.451364                  -0.363815           0.445544
# 0.25                   0.492492                  -0.302007           0.485656
# 0.50                   0.451564                  -0.358777           0.446115
# 0.75                   0.492924                  -0.298105           0.486154
# 1.00                   0.547485                  -0.255592           0.545881
# 2.00                   0.504774                  -0.281667           0.496418
# 5.00                   0.476702                  -0.298604           0.474459
# 8.00                   0.543906                  -0.251355           0.542439
# 10.00                  0.549099                  -0.248358           0.561583
# 50.00                  0.551351                  -0.248643           0.500000
# 100.00                 0.551351                  -0.248643           0.500000
#
#              mean_test_precision  mean_test_recall
# param_gamma
# 0.00                    0.460664          0.470129
# 0.25                    0.534111          0.551198
# 0.50                    0.464597          0.471103
# 0.75                    0.533201          0.553404
# 1.00                    0.543027          0.650637
# 2.00                    0.534007          0.585559
# 5.00                    0.468187          0.549220
# 8.00                    0.547534          0.786655
# 10.00                   0.533178          0.805940
# 50.00                   0.551351          1.000000
# 100.00                  0.551351          1.000000

# %% [markdown]
# #### Lambda (L2) Regularization Parameter
# To prevent overfitting, you can use an L1 regularization parameter. But in this test, it has no visible effect on performance.

# %%
hyper_results(performance, 'param_reg_lambda')
# Out:
#                   mean_test_accuracy  mean_test_neg_brier_score  \
# param_reg_lambda
# 0.0                         0.486401                  -0.310928
# 0.5                         0.508509                  -0.283366
# 1.0                         0.488217                  -0.305266
# 1.5                         0.509822                  -0.282029
#
#                   mean_test_roc_auc  mean_test_precision  mean_test_recall
# param_reg_lambda
# 0.0                        0.480624             0.506216          0.563203
# 0.5                        0.503273             0.537688          0.616678
# 1.0                        0.483151             0.505669          0.568439
# 1.5                        0.503848             0.537091          0.624992

# %% [markdown]
# #### Learning Rate (Eta)

# %% [markdown]
# Prevents overfitting by minimizing the impact of new trees on the overall prediction. Over time, adjustments become fine-grained.
#
# 'eta': [0.05, 0.005, 0.001, 0.00001],

# %%
hyper_results(performance, 'param_eta')
# Out:
#            mean_test_accuracy  mean_test_neg_brier_score  mean_test_roc_auc  \
# param_eta
# 0.0001               0.556569                  -0.249907           0.530433
# 0.0005               0.561781                  -0.249342           0.553646
# 0.0010               0.553416                  -0.249250           0.529476
# 0.0100               0.507946                  -0.264347           0.503184
# 0.0500               0.540465                  -0.253594           0.519526
# 0.0800               0.500188                  -0.277914           0.494654
# 0.1000               0.455506                  -0.335219           0.448197
# 0.1200               0.491441                  -0.287282           0.489354
# 0.2500               0.446463                  -0.367235           0.441130
# 0.4000               0.480687                  -0.318597           0.473013
# 0.5000               0.447764                  -0.387743           0.440022
#
#            mean_test_precision  mean_test_recall
# param_eta
# 0.0001                0.555310          0.828889
# 0.0005                0.568668          0.714956
# 0.0010                0.551006          0.838452
# 0.0100                0.489289          0.666013
# 0.0500                0.532979          0.887753
# 0.0800                0.525834          0.625792
# 0.1000                0.447722          0.492462
# 0.1200                0.527993          0.594151
# 0.2500                0.458368          0.468289
# 0.4000                0.526356          0.541917
# 0.5000                0.484918          0.465158

# %% [markdown]
# #### Subsample %
# You can also fiddle with dropout layers / subsampling within the model, but no big effects here.

# %%
hyper_results(performance, 'param_subsample')
# Out:
#                  mean_test_accuracy  mean_test_neg_brier_score  \
# param_subsample
# 0.7                        0.495652                  -0.298707
# 1.0                        0.494861                  -0.299014
#
#                  mean_test_roc_auc  mean_test_precision  mean_test_recall
# param_subsample
# 0.7                       0.490898             0.532347          0.579158
# 1.0                       0.488639             0.502408          0.592493

# %% [markdown]
# # Selecting One Model

# %%
select_cols = [
    'model_id',
    'param_booster',
    'param_max_depth',
    'param_min_child_weight',
    'param_reg_lambda',
    'param_gamma',
    'param_eta',
    'param_subsample',
    'mean_test_accuracy',
    'mean_test_neg_brier_score',
    'mean_test_roc_auc',
    'mean_test_precision',
    'mean_test_recall',
    'features'
]

# %%
top_100 = performance[select_cols].sort_values('mean_test_neg_brier_score', ascending=False).head(100)

# %%
for col in hypers:
    print(top_100[col].value_counts())
# Out:
# 1.0    72
# 0.7     8
# Name: param_subsample, dtype: int64
# 8     31
# 4     31
# 2     28
# 16     5
# 32     5
# Name: param_max_depth, dtype: int64
# 20    36
# 12    26
# 16    18
# 48    12
# 24     8
# Name: param_min_child_weight, dtype: int64
# 1.0    25
# 0.0    23
# 1.5    17
# 0.5    15
# Name: param_reg_lambda, dtype: int64
# 8.0     62
# 1.0     12
# 10.0     8
# 5.0      6
# 0.5      6
# 0.0      6
# Name: param_gamma, dtype: int64
# 0.12    24
# 0.01    24
# 0.08    24
# 0.40    14
# 0.05    12
# 0.10     2
# Name: param_eta, dtype: int64
# no_credit    100
# Name: features, dtype: int64

# %%
# Choose by hand the most effective hyperparameters for the model
best_hypers = {
    'param_max_depth': 4,
    'param_min_child_weight': 16,
    'param_reg_lambda': 0,
    'param_gamma': 10,
    'param_eta': 0.10,
    'param_subsample': 0.7,
}

# %% [markdown]
# # Rebuild the Best Model

# %%
# Import data
data = pd.read_pickle('output_data/02_data.pkl')
data_dict = pd.read_pickle('output_data/02_data_dict.pkl')

X_train = pd.read_pickle('output_data/04_X_train.pkl')
X_test = pd.read_pickle('output_data/04_X_test.pkl')

y_train = pd.read_pickle('output_data/04_y_train.pkl')
y_test = pd.read_pickle('output_data/04_y_test.pkl')
